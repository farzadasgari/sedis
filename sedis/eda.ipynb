# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, kstest, kendalltau
from statsmodels.graphics.gofplots import qqplot

# %%
plt.style.use('seaborn-v0_8-white')
plt.rcParams.update({
    'font.family': 'Arial',
    'font.size': 12,
    'axes.labelsize': 12,
    'axes.titlesize': 14,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'legend.fontsize': 10,
    'axes.linewidth': 0.8,
    'grid.linewidth': 0.5,
    'lines.linewidth': 1.5,
    'figure.dpi': 600,
    'savefig.dpi': 600,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'axes.grid': True,
    'grid.color': '0',
})

# %%
path = "../dataset/data.csv"
df = pd.read_csv(path, parse_dates=['Date'])
columns = df.drop('Date', axis=1).columns
df.head()
# Out:
#         Date  Turbidity    DO  Chl-a   Discharge    Height  Temperature  \
# 0 2019-04-15       68.1  10.2    2.8  122.045408  2.197608         14.6
# 1 2019-04-20       43.6  10.6    6.0   96.277120  2.033016         17.2
# 2 2019-05-05      152.0   8.6    3.2  180.944352  2.526792         18.0
# 3 2019-09-27      153.0   7.8    1.6  212.092832  2.685288         23.4
# 4 2019-12-31       22.2  13.1    2.1  175.847328  2.508504          2.7
#
#          B1        B2        B3  ...     MNDWI     GNDVI      SDDI      NDTI  \
# 0  0.029657  0.049351  0.075480  ...  0.374551 -0.150643 -0.170720  0.085153
# 1  0.020847  0.031492  0.062739  ...  0.343369 -0.229942  0.003395 -0.001698
# 2  0.057005  0.074017  0.095155  ...  0.262853  0.136803 -0.187451  0.093452
# 3  0.045093  0.058916  0.085228  ...  0.453808  0.046520 -0.216945  0.108049
# 4  0.022669  0.043136  0.063866  ...  0.288010 -0.226803 -0.055859  0.027922
#
#          BR      NDWI      NDPI      NDCI  2BDA_Chl        RR
# 0  0.551217  0.150643 -0.374551  0.063141  0.012068  1.134792
# 1  0.503659  0.229942 -0.343369  0.132095  0.019033  1.304399
# 2  0.644899 -0.136803 -0.262853  0.075063  0.018629  1.162309
# 3  0.556456 -0.046520 -0.453808  0.071456  0.016295  1.153910
# 4  0.638716  0.226803 -0.288010  0.004913  0.000667  1.009874
#
# [5 rows x 30 columns]

# %%
def test_normality(data, column, alpha=0.05):
    if column not in data.columns:
        raise ValueError(f"Column '{column}' not found in DataFrame.")
    
    valid_data = data[column].dropna()
        
    if not np.issubdtype(valid_data.dtype, np.number):
        raise ValueError(f"Column '{column}' contains non-numeric data.")
    
    stat_sw, p_sw = shapiro(valid_data)
    
    print(f'Shapiro-Wilk Test for {column}:')
    print(f'Statistic: {stat_sw:.3f}, p-value: {p_sw:.3e}')
    if p_sw > alpha:
        print(f'{column} appears normally distributed (p > {alpha}).')
    else:
        print(f'{column} does not appear normally distributed (p ≤ {alpha}).')
        
    print()
    return stat_sw, p_sw

# %%
results = [test_normality(df, col) for col in columns]
# Out:
# Shapiro-Wilk Test for Turbidity:
# Statistic: 0.739, p-value: 1.726e-13
# Turbidity does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for DO:
# Statistic: 0.962, p-value: 1.439e-03
# DO does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for Chl-a:
# Statistic: 0.944, p-value: 6.192e-05
# Chl-a does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for Discharge:
# Statistic: 0.781, p-value: 2.955e-12
# Discharge does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for Height:
# Statistic: 0.845, p-value: 5.130e-10
# Height does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for Temperature:
# Statistic: 0.934, p-value: 1.476e-05
# Temperature does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B1:
# Statistic: 0.950, p-value: 1.681e-04
# B1 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B2:
# Statistic: 0.974, p-value: 1.709e-02
# B2 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B3:
# Statistic: 0.964, p-value: 2.222e-03
# B3 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B4:
# Statistic: 0.936, p-value: 1.966e-05
# B4 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B5:
# Statistic: 0.926, p-value: 4.067e-06
# B5 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B6:
# Statistic: 0.950, p-value: 1.689e-04
# B6 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B7:
# Statistic: 0.953, p-value: 2.947e-04
# B7 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B8:
# Statistic: 0.959, p-value: 8.670e-04
# B8 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B8A:
# Statistic: 0.960, p-value: 1.088e-03
# B8A does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B9:
# Statistic: 0.975, p-value: 2.405e-02
# B9 does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for B11:
# Statistic: 0.989, p-value: 4.448e-01
# B11 appears normally distributed (p > 0.05).
#
# Shapiro-Wilk Test for B12:
# Statistic: 0.987, p-value: 2.905e-01
# B12 appears normally distributed (p > 0.05).
#
# Shapiro-Wilk Test for WVP:
# Statistic: 0.902, p-value: 1.949e-07
# WVP does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for MNDWI:
# Statistic: 0.951, p-value: 2.299e-04
# MNDWI does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for GNDVI:
# Statistic: 0.927, p-value: 5.247e-06
# GNDVI does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for SDDI:
# Statistic: 0.980, p-value: 5.917e-02
# SDDI appears normally distributed (p > 0.05).
#
# Shapiro-Wilk Test for NDTI:
# Statistic: 0.980, p-value: 6.067e-02
# NDTI appears normally distributed (p > 0.05).
#
# Shapiro-Wilk Test for BR:
# Statistic: 0.983, p-value: 1.309e-01
# BR appears normally distributed (p > 0.05).
#
# Shapiro-Wilk Test for NDWI:
# Statistic: 0.927, p-value: 5.247e-06
# NDWI does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for NDPI:
# Statistic: 0.951, p-value: 2.299e-04
# NDPI does not appear normally distributed (p ≤ 0.05).
#
# Shapiro-Wilk Test for NDCI:
# Statistic: 0.980, p-value: 6.082e-02
# NDCI appears normally distributed (p > 0.05).
#
# Shapiro-Wilk Test for 2BDA_Chl:
# Statistic: 0.980, p-value: 6.921e-02
# 2BDA_Chl appears normally distributed (p > 0.05).
#
# Shapiro-Wilk Test for RR:
# Statistic: 0.982, p-value: 1.095e-01
# RR appears normally distributed (p > 0.05).

# %%
table_data = [
    ['SW'] + [f'{stat_sw:.2f}' for stat_sw, _ in results],
    ['p_SW'] + [f'{p_sw:.1e}' for _, p_sw in results],
    ['Normality'] + ['Normal' if p_sw > 0.05 else 'Not Normal' for _, p_sw in results]
]
table = pd.DataFrame(
    data=[row[1:] for row in table_data],
    index=[row[0] for row in table_data],
    columns=columns
)
table
# Out:
#             Turbidity          DO       Chl-a   Discharge      Height  \
# SW               0.74        0.96        0.94        0.78        0.85
# p_SW          1.7e-13     1.4e-03     6.2e-05     3.0e-12     5.1e-10
# Normality  Not Normal  Not Normal  Not Normal  Not Normal  Not Normal
#
#           Temperature          B1          B2          B3          B4  ...  \
# SW               0.93        0.95        0.97        0.96        0.94  ...
# p_SW          1.5e-05     1.7e-04     1.7e-02     2.2e-03     2.0e-05  ...
# Normality  Not Normal  Not Normal  Not Normal  Not Normal  Not Normal  ...
#
#                 MNDWI       GNDVI     SDDI     NDTI       BR        NDWI  \
# SW               0.95        0.93     0.98     0.98     0.98        0.93
# p_SW          2.3e-04     5.2e-06  5.9e-02  6.1e-02  1.3e-01     5.2e-06
# Normality  Not Normal  Not Normal   Normal   Normal   Normal  Not Normal
#
#                  NDPI     NDCI 2BDA_Chl       RR
# SW               0.95     0.98     0.98     0.98
# p_SW          2.3e-04  6.1e-02  6.9e-02  1.1e-01
# Normality  Not Normal   Normal   Normal   Normal
#
# [3 rows x 29 columns]

# %%
for col in columns:
    plt.figure(figsize=(10, 4))
    
    plt.subplot(1, 2, 1)
    sns.kdeplot(df[col].dropna(), color='navy', linewidth=1.5)
    plt.xlabel(col.replace('_', ' ').title())
    plt.ylabel('Frequency')
    # plt.title(f'Histogram of {col.replace("_", " ").title()}', pad=10)
    
    plt.subplot(1, 2, 2)
    qqplot(df[col].dropna(), line='s', ax=plt.gca(), marker='.', markersize=12, alpha=0.6)
    plt.xlabel('Theoretical Quantiles')
    plt.ylabel('Sample Quantiles')
    # plt.title(f'Q-Q Plot of {col.replace("_", " ").title()}', pad=10)
    
    plt.tight_layout()
    plt.savefig(
        f'../plots/eda/normality/{col}.png',
        format='png',
        bbox_inches='tight',
        transparent=True,
        dpi=600
    )
    plt.close()

# %%
columns
# Out:
# Index(['Turbidity', 'DO', 'Chl-a', 'Discharge', 'Height', 'Temperature', 'B1',
#        'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12',
#        'WVP', 'MNDWI', 'GNDVI', 'SDDI', 'NDTI', 'BR', 'NDWI', 'NDPI', 'NDCI',
#        '2BDA_Chl', 'RR'],
#       dtype='object')

# %%
def correlation(data, name="dataset"):
    corr = data.corr(numeric_only=True, method="pearson")
    mask = np.triu(np.ones_like(corr, dtype=bool))
    np.fill_diagonal(mask, False)
    
    plt.figure(figsize=(12, 10))
    heatmap = sns.heatmap(
            corr, mask=mask, vmin=-1, vmax=1,
            annot=True, fmt=".2f",
            cmap='coolwarm',
            annot_kws={"size": 7, "weight": "bold"},
            cbar_kws={"shrink": .8, "ticks": np.linspace(-1, 1, 5)}
    )
    colorbar = heatmap.collections[0].colorbar
    colorbar.set_label('Pearson Correlation Coefficients (r)', fontsize=14)
    heatmap.figure.axes[-1].yaxis.label.set_size(10)
    heatmap.figure.axes[-1].tick_params(labelsize=14)
    plt.grid(False)
    plt.tight_layout()
    plt.savefig(
        f'../plots/eda/correlation/{name}.png',
        format='png',
        bbox_inches='tight',
        transparent=True,
        dpi=600
    )
    plt.close()

# %%
correlation(df, name="full")

# %%
def seasonal_correlation(data):
    seasons = {
        'Spring': [3, 4, 5],
        'Summer': [6, 7, 8],
        'Autumn': [9, 10, 11],
        'Winter': [12, 1, 2]
    }
    
    for idx, (season, months) in enumerate(seasons.items()):
        season_data = data[data['Date'].dt.month.isin(months)]
        corr = season_data.corr(method="pearson")

        corr = season_data.corr(numeric_only=True, method="pearson")
        mask = np.triu(np.ones_like(corr, dtype=bool))
        np.fill_diagonal(mask, False)
        
        plt.figure(figsize=(12, 10))
        heatmap = sns.heatmap(
                corr, mask=mask, vmin=-1, vmax=1,
                annot=True, fmt=".2f",
                cmap='coolwarm',
                annot_kws={"size": 7, "weight": "bold"},
                cbar_kws={"shrink": .6, "ticks": np.linspace(-1, 1, 5)}
        )
        colorbar = heatmap.collections[0].colorbar
        colorbar.set_label('Pearson Correlation Coefficients (r)', fontsize=14)
        colorbar.ax.tick_params(labelsize=12)
        heatmap.figure.axes[-1].yaxis.label.set_size(10)
        heatmap.figure.axes[-1].tick_params(labelsize=14)
        plt.grid(False)
        plt.tight_layout()
        plt.savefig(
            f'../plots/eda/correlation/seasonal-{season}.png',
            format='png',
            bbox_inches='tight',
            transparent=True,
            dpi=600
        )
        plt.close()

# %%
seasonal_correlation(df)
